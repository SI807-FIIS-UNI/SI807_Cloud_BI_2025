# %% [markdown]
# # EDA PARA RETAIL TRANSACTIONS

# %%
import pandas as pd
import numpy as np

# %%
# Carga del CSV
ruta = 'C:\\Users\\jairo\\Documents\\Proyectos\\aradiel_25-2\\SI807_Cloud_BI_2025\\grupo10_sutran\\ExFinal\\SolucionIndividual\\DelRio_Gutierrez\\bronce\\Retail_Transactions_Dataset.csv'
df = pd.read_csv(ruta)

# %% [markdown]
# ## VISUALIZACIÓN Y VISTA GENERAL DE DATOS

# %%
print("Shape:", df.shape)
df.head()
# Out:
# Shape: (1000000, 13)
#    Transaction_ID                 Date      Customer_Name  \
# 0      1000000000  2022-01-21 06:27:29       Stacey Price
# 1      1000000001  2023-03-01 13:01:21   Michelle Carlson
# 2      1000000002  2024-03-21 15:37:04        Lisa Graves
# 3      1000000003  2020-10-31 09:59:47  Mrs. Patricia May
# 4      1000000004  2020-12-10 00:59:59     Susan Mitchell
#
#                                              Product  Total_Items  Total_Cost  \
# 0        ['Ketchup', 'Shaving Cream', 'Light Bulbs']            3       71.65
# 1  ['Ice Cream', 'Milk', 'Olive Oil', 'Bread', 'P...            2       25.93
# 2                                        ['Spinach']            6       41.49
# 3                             ['Tissues', 'Mustard']            1       39.34
# 4                                      ['Dish Soap']           10       16.42
#
#    Payment_Method           City        Store_Type  Discount_Applied  \
# ...

# %% [markdown]
# ## TIPO DE DATOS Y VALORES

# %%
df.dtypes
# Out:
# Transaction_ID         int64
# Date                  object
# Customer_Name         object
# Product               object
# Total_Items            int64
# Total_Cost           float64
# Payment_Method        object
# City                  object
# Store_Type            object
# Discount_Applied        bool
# Customer_Category     object
# Season                object
# Promotion             object
# dtype: object

# %%
# Valores nulos
df.isnull().sum()
# Out:
# Transaction_ID            0
# Date                      0
# Customer_Name             0
# Product                   0
# Total_Items               0
# Total_Cost                0
# Payment_Method            0
# City                      0
# Store_Type                0
# Discount_Applied          0
# Customer_Category         0
# Season                    0
# Promotion            333943
# dtype: int64

# %%
# Valores únicos por columna
df.nunique()
# Out:
# Transaction_ID       1000000
# Date                  996337
# Customer_Name         329738
# Product               571947
# Total_Items               10
# Total_Cost              9501
# Payment_Method             4
# City                      10
# Store_Type                 6
# Discount_Applied           2
# Customer_Category          8
# Season                     4
# Promotion                  2
# dtype: int64

# %%
# Estadísticas básicas
df.describe(include='all')
# Out:
#         Transaction_ID                 Date  Customer_Name         Product  \
# count     1.000000e+06              1000000        1000000         1000000
# unique             NaN               996337         329738          571947
# top                NaN  2024-03-13 12:44:06  Michael Smith  ['Toothpaste']
# freq               NaN                    3            454            4893
# mean      1.000500e+09                  NaN            NaN             NaN
# std       2.886753e+05                  NaN            NaN             NaN
# min       1.000000e+09                  NaN            NaN             NaN
# 25%       1.000250e+09                  NaN            NaN             NaN
# 50%       1.000500e+09                  NaN            NaN             NaN
# 75%       1.000750e+09                  NaN            NaN             NaN
# max       1.001000e+09                  NaN            NaN             NaN
#
# ...

# %%
# Ver muestras de columnas clave
print("\nProductos (sample):")
print(df['Product'].sample(5).values)

print("\nMétodos de pago:", df['Payment_Method'].unique())
print("Tiendas:", df['Store_Type'].unique())
print("Temporadas:", df['Season'].unique())
# Out:
# Productos (sample):
# ["['Dustpan', 'Bath Towels', 'Water', 'Shrimp', 'Toothpaste']"
#  "['Plant Fertilizer', 'Salmon', 'Carrots']" "['Hair Gel', 'Soap']"
#  "['Beef', 'Shower Gel', 'Tea', 'Eggs']"
#  "['Garden Hose', 'Cleaning Spray', 'Dish Soap', 'Orange']"]
#
# Métodos de pago: ['Mobile Payment' 'Cash' 'Credit Card' 'Debit Card']
# Tiendas: ['Warehouse Club' 'Specialty Store' 'Department Store' 'Pharmacy'
#  'Supermarket' 'Convenience Store']
# Temporadas: ['Winter' 'Fall' 'Spring' 'Summer']
