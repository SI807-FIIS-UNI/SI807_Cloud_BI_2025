# %% [markdown]
# ## ETAPA 1: CARGA INICIAL DE DATOS

# %% [markdown]
# Cargar los datasets desde Cloud Storage

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder.appName("ETL_SUTRAN").getOrCreate()

# Ruta base en Cloud Storage
bucket_path = "gs://sutran-bucket-2025/raw/"

# Leer los 3 datasets
df_personas = spark.read.option("header", True).option("inferSchema", True).csv(bucket_path + "BBDD_ONSV-PERSONAS_2021-2023.csv")
df_vehiculos = spark.read.option("header", True).option("inferSchema", True).csv(bucket_path + "BBDD_ONSV-VEHICULOS_2021-2023.csv")
df_siniestros = spark.read.option("header", True).option("inferSchema", True).csv(bucket_path + "BBDD_ONSV-SINIESTROS_2021-2023.csv")
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/11/17 16:04:46 INFO SparkEnv: Registering MapOutputTracker
# 25/11/17 16:04:46 INFO SparkEnv: Registering BlockManagerMaster
# 25/11/17 16:04:47 INFO SparkEnv: Registering BlockManagerMasterHeartbeat
# 25/11/17 16:04:47 INFO SparkEnv: Registering OutputCommitCoordinator

# %% [markdown]
# Verificamos que se cargaron bien

# %%
df_personas.printSchema()
df_vehiculos.printSchema()
df_siniestros.printSchema()
# Out:
# root
#  |-- CODIGO_SINIESTRO: string (nullable = true)
#  |-- CODIGO_VEHICULO: string (nullable = true)
#  |-- CODIGO_PERSONA: string (nullable = true)
#  |-- DEPARTAMENTO: string (nullable = true)
#  |-- PROVINCIA: string (nullable = true)
#  |-- DISTRITO: string (nullable = true)
#  |-- TIPO_PERSONA: string (nullable = true)
#  |-- GRAVEDAD: string (nullable = true)
#  |-- LUGAR_ATENCION_LESIONADO: string (nullable = true)
#  |-- LUGAR_DE_DEFUNCION: string (nullable = true)
#  |-- SITUACION_DE_PERSONA: string (nullable = true)
#  |-- PAIS_DE_NACIONALIDAD: string (nullable = true)
#  |-- EDAD: string (nullable = true)
#  |-- SEXO: string (nullable = true)
#  |-- POSEE_LICENCIA: string (nullable = true)
#  |-- ESTADO_LICENCIA: string (nullable = true)
#  |-- CLASE_LICENCIA: string (nullable = true)
#  |-- SE_SOMETIO_A_DOSAJE_ETILICO_CUALITATIVO: string (nullable = true)
#  |-- RESULTADO_DEL_DOSAJE_ETILICO_CUALITATIVO: string (nullable = true)
#  |-- SE_SOMETIO_A_DOSAJE_ETILICO_CUANTITATIVO: string (nullable = true)
#  |-- VEHICULO: string (nullable = true)
#  |-- FECHA: string (nullable = true)
#  |-- ANIO: integer (nullable = true)
#  |-- MES: string (nullable = true)
#  |-- DIA: string (nullable = true)
#  |-- HORA: integer (nullable = true)
#  |-- CLASE_DE_SINIESTRO: string (nullable = true)
#  |-- CAUSA: string (nullable = true)
#  |-- CAUSA_ESPECIFICA: string (nullable = true)
#  |-- TIPO_DE_VIA: string (nullable = true)
#  |-- CODIGO_DE_CARRETERA: string (nullable = true)
#  |-- RED_VIAL: string (nullable = true)
#
# root
#  |-- CODIGO_SINIESTRO: string (nullable = true)
#  |-- CODIGO_VEHICULO: string (nullable = true)
#  |-- DEPARTAMENTO: string (nullable = true)
#  |-- PROVINCIA: string (nullable = true)
#  |-- DISTRITO: string (nullable = true)
#  |-- SITUACION_VEHICULO: string (nullable = true)
#  |-- ESTADO_MODALIDAD: string (nullable = true)
#  |-- MODALIDAD_DE_TRANSPORTE: string (nullable = true)
#  |-- ELEMENTO_TRANSPORTADO: string (nullable = true)
#  |-- AMBITO_SERVICIO: string (nullable = true)
#  |-- POSEE_SEGURO: string (nullable = true)
#  |-- ESTADO_SOAT: string (nullable = true)
#  |-- TIPO_SEGURO: string (nullable = true)
#  |-- COMPANIA_SEGURO: string (nullable = true)
#  |-- POSEE_CITV: string (nullable = true)
#  |-- ESTADO_CITV: string (nullable = true)
#  |-- LUGAR_IMPACTO_VEHICULO: string (nullable = true)
#  |-- VEHICULO: string (nullable = true)
#  |-- TIPO_SINIESTRO: string (nullable = true)
#  |-- FECHA: string (nullable = true)
#  |-- ANO: integer (nullable = true)
#  |-- MES: string (nullable = true)
#  |-- DIA: string (nullable = true)
#  |-- HORA: integer (nullable = true)
#  |-- CODIGO_DE_CARRETERA: string (nullable = true)
#  |-- TIPO_DE_VIA: string (nullable = true)
#
# root
#  |-- CODIGO_SINIESTRO: string (nullable = true)
#  |-- FECHA_SINIESTRO: string (nullable = true)
#  |-- HORA_SINIESTRO: timestamp (nullable = true)
#  |-- CLASE_SINIESTRO: string (nullable = true)
#  |-- CANTIDAD_DE_FALLECIDOS: integer (nullable = true)
#  |-- CANTIDAD_DE_LESIONADOS: integer (nullable = true)
#  |-- CANTIDAD_DE_VEHICULOS_DANADOS: integer (nullable = true)
#  |-- DEPARTAMENTO: string (nullable = true)
#  |-- PROVINCIA: string (nullable = true)
#  |-- DISTRITO: string (nullable = true)
#  |-- ZONA: string (nullable = true)
#  |-- TIPO_DE_VIA: string (nullable = true)
#  |-- RED_VIAL: string (nullable = true)
#  |-- COD_CARRETERA: string (nullable = true)
#  |-- EXISTE_CICLOVIA: string (nullable = true)
#  |-- COORDENADAS_LATITUD: double (nullable = true)
#  |-- COORDENADAS_LONGITUD: double (nullable = true)
#  |-- CONDICION_CLIMATICA: string (nullable = true)
#  |-- ZONIFICACION: string (nullable = true)
#  |-- CARACTERISTICAS_DE_VIA: string (nullable = true)
#  |-- PERFIL_LONGITUDINAL_VIA: string (nullable = true)
#  |-- SUPERFICIE_DE_CALZADA: string (nullable = true)
#  |-- EXISTE_SENAL_VERTICAL: string (nullable = true)
#  |-- CLASIFICACION_DE_LA_SENAL_VERTICAL_N_1: string (nullable = true)
#  |-- CLASIFICACION_DE_LA_SENAL_VERTICAL_N_2: string (nullable = true)
#  |-- EXISTE_SENAL_HORIZONTAL: string (nullable = true)
#  |-- CAUSA_FACTOR_PRINCIPAL: string (nullable = true)
#  |-- CAUSA_ESPECIFICA: string (nullable = true)

# %%
df_personas.show(5)
df_vehiculos.show(5)
df_siniestros.show(5)
# Out:
# 25/11/17 16:05:27 WARN package: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# +----------------+---------------+-----------------+------------+---------+----------+----------------+---------+------------------------+------------------+--------------------+--------------------+----+---------+--------------+---------------+--------------+---------------------------------------+----------------------------------------+----------------------------------------+-----------------+----------+----+-----+-------+----+------------------+--------------------+--------------------+--------------------+-------------------+-------------+
# |CODIGO_SINIESTRO|CODIGO_VEHICULO|   CODIGO_PERSONA|DEPARTAMENTO|PROVINCIA|  DISTRITO|    TIPO_PERSONA| GRAVEDAD|LUGAR_ATENCION_LESIONADO|LUGAR_DE_DEFUNCION|SITUACION_DE_PERSONA|PAIS_DE_NACIONALIDAD|EDAD|     SEXO|POSEE_LICENCIA|ESTADO_LICENCIA|CLASE_LICENCIA|SE_SOMETIO_A_DOSAJE_ETILICO_CUALITATIVO|RESULTADO_DEL_DOSAJE_ETILICO_CUALITATIVO|SE_SOMETIO_A_DOSAJE_ETILICO_CUANTITATIVO|         VEHICULO|     FECHA|ANIO|  MES|    DIA|HORA|CLASE_DE_SINIESTRO|               CAUSA|    CAUSA_ESPECIFICA|         TIPO_DE_VIA|CODIGO_DE_CARRETERA|     RED_VIAL|
# +----------------+---------------+-----------------+------------+---------+----------+----------------+---------+------------------------+------------------+--------------------+--------------------+----+---------+--------------+---------------+--------------+---------------------------------------+----------------------------------------+----------------------------------------+-----------------+----------+----+-----+-------+----+------------------+--------------------+--------------------+--------------------+-------------------+-------------+
# |   A-2021-01-141|V-2021-01-141-1|P-2021-01-141-1-2|    APURIMAC|  ABANCAY|   ABANCAY|        PASAJERO|LESIONADO|                    null|              null|        IDENTIFICADO|                null|  20| FEMENINO|  SE DESCONOCE|   NO CONDUCTOR|  NO CONDUCTOR|                                   null|                           NO SE REALIZO|                                    null|      MOTOCICLETA|17/01/2021|2021|ENERO|DOMINGO|  16|          DESPISTE|IMPRUDENCIA DEL C...|FATIGA Y/O CANSANCIO|CARRETERA DEPARTA...|             AP-103|DEPARTAMENTAL|
# |   A-2021-01-177|V-2021-01-177-1|P-2021-01-177-1-3|         ICA|      ICA|  SANTIAGO|        OCUPANTE|LESIONADO|                    null|              null|        IDENTIFICADO|                null|  35| FEMENINO|  SE DESCONOCE|   NO CONDUCTOR|  NO CONDUCTOR|                                   null|                           NO SE REALIZO|                                    null|CAMIONETA PICK UP|21/01/2021|2021|ENERO| JUEVES|  16|          DESPISTE|NEGLIGENCIA DEL C...|CONDUCIR CON FALL...|  CARRETERA NACIONAL|              PE-1S|     NACIONAL|
# |   A-2021-01-177|V-2021-01-177-1|P-2021-01-177-1-4|         ICA|      ICA|  SANTIAGO|        OCUPANTE|LESIONADO|                    null|              null|        IDENTIFICADO|                null|   7|MASCULINO|  SE DESCONOCE|   NO CONDUCTOR|  NO CONDUCTOR|                                   null|                           NO SE REALIZO|                                    null|CAMIONETA PICK UP|21/01/2021|2021|ENERO| JUEVES|  16|          DESPISTE|NEGLIGENCIA DEL C...|CONDUCIR CON FALL...|  CARRETERA NACIONAL|              PE-1S|     NACIONAL|
# |   A-2021-01-177|V-2021-01-177-1|P-2021-01-177-1-5|         ICA|      ICA|  SANTIAGO|        OCUPANTE|LESIONADO|                    null|              null|        IDENTIFICADO|                null|  13|MASCULINO|  SE DESCONOCE|   NO CONDUCTOR|  NO CONDUCTOR|                                   null|                           NO SE REALIZO|                                    null|CAMIONETA PICK UP|21/01/2021|2021|ENERO| JUEVES|  16|          DESPISTE|NEGLIGENCIA DEL C...|CONDUCIR CON FALL...|  CARRETERA NACIONAL|              PE-1S|     NACIONAL|
# |   A-2021-01-186|V-2021-01-186-1|P-2021-01-186-1-3|    AREQUIPA| AREQUIPA|PAUCARPATA|CONDUCTOR FUGADO|    ILESO|                    null|              null|        IDENTIFICADO|                PERÚ|  30|MASCULINO|  SE DESCONOCE|   SIN LICENCIA|  SIN LICENCIA|                                   null|                           NO SE REALIZO|                                      NO|      MOTOCICLETA|24/01/2021|2021|ENERO|DOMINGO|  19|    ATROPELLO FUGA|IMPRUDENCIA DEL C...| EXCESO DE VELOCIDAD|             AVENIDA|     NO CORRESPONDE|       URBANO|
# +----------------+---------------+-----------------+------------+---------+----------+----------------+---------+------------------------+------------------+--------------------+--------------------+----+---------+--------------+---------------+--------------+---------------------------------------+----------------------------------------+----------------------------------------+-----------------+----------+----+-----+-------+----+------------------+--------------------+--------------------+--------------------+-------------------+-------------+
# only showing top 5 rows
#
# +----------------+---------------+------------+--------------------+--------+------------------+----------------+-----------------------+---------------------+---------------+------------+-----------+-----------+---------------+----------+-----------+----------------------+-----------------+--------------+----------+----+-----+-------+----+-------------------+-----------+
# |CODIGO_SINIESTRO|CODIGO_VEHICULO|DEPARTAMENTO|           PROVINCIA|DISTRITO|SITUACION_VEHICULO|ESTADO_MODALIDAD|MODALIDAD_DE_TRANSPORTE|ELEMENTO_TRANSPORTADO|AMBITO_SERVICIO|POSEE_SEGURO|ESTADO_SOAT|TIPO_SEGURO|COMPANIA_SEGURO|POSEE_CITV|ESTADO_CITV|LUGAR_IMPACTO_VEHICULO|         VEHICULO|TIPO_SINIESTRO|     FECHA| ANO|  MES|    DIA|HORA|CODIGO_DE_CARRETERA|TIPO_DE_VIA|
# +----------------+---------------+------------+--------------------+--------+------------------+----------------+-----------------------+---------------------+---------------+------------+-----------+-----------+---------------+----------+-----------+----------------------+-----------------+--------------+----------+----+-----+-------+----+-------------------+-----------+
# |   A-2021-01-108|V-2021-01-108-1|         ICA|               NASCA| MARCONA|      IDENTIFICADO|      HABILITADO|             PARTICULAR|             PERSONAS|   NO SE CONOCE|        null|    VIGENTE|       null|    LA POSITIVA|      null|  NO APLICA|                  null|      MOTOCICLETA|        CHOQUE|11/01/2021|2021|ENERO|  LUNES|  10|             IC-824|  CARRETERA|
# |   A-2021-01-108|V-2021-01-108-2|         ICA|               NASCA| MARCONA|      IDENTIFICADO|      HABILITADO|             PARTICULAR|                 null|           null|        null|    VIGENTE|       null|         MAPFRE|      null|    VENCIDO|                  null|CAMIONETA PICK UP|        CHOQUE|11/01/2021|2021|ENERO|  LUNES|  10|             IC-824|  CARRETERA|
# |   A-2021-01-109|V-2021-01-109-1|  LAMBAYEQUE|          LAMBAYEQUE|  MOTUPE|      IDENTIFICADO|  NO CORRESPONDE|                  CARGA| CARGA Y/O MERCANCÍAS|      DISTRITAL|        null|    VIGENTE|       null|          OTROS|      null|NO REGISTRA|        FRONTAL-CENTRO|           CAMIÓN|     ATROPELLO|10/01/2021|2021|ENERO|DOMINGO|   2|             PE-1NJ|  CARRETERA|
# |   A-2021-01-114|V-2021-01-114-1|  SAN MARTIN|               RIOJA|   POSIC|      IDENTIFICADO|      HABILITADO|             PARTICULAR|                 null|           null|        null|NO REGISTRA|       null|           null|      null|NO REGISTRA|                  null|      MOTOCICLETA|     VOLCADURA|14/01/2021|2021|ENERO| JUEVES|   0|             SM-114|  CARRETERA|
# |   A-2021-01-119|V-2021-01-119-1|    MOQUEGUA|GENERAL SANCHEZ C...|  ICHUÑA|      IDENTIFICADO|      HABILITADO|             PARTICULAR|                 null|           null|        null|    VIGENTE|       null|    LA POSITIVA|      null|    VIGENTE|                  null|        AUTOMÓVIL|      DESPISTE|12/01/2021|2021|ENERO| MARTES|  12|             MO-103|  CARRETERA|
# +----------------+---------------+------------+--------------------+--------+------------------+----------------+-----------------------+---------------------+---------------+------------+-----------+-----------+---------------+----------+-----------+----------------------+-----------------+--------------+----------+----+-----+-------+----+-------------------+-----------+
# only showing top 5 rows
#
# +----------------+---------------+-------------------+---------------+----------------------+----------------------+-----------------------------+------------+---------+--------------------+------+-----------+--------+--------------+---------------+-------------------+--------------------+-------------------+------------+----------------------+-----------------------+---------------------+---------------------+--------------------------------------+--------------------------------------+-----------------------+----------------------+--------------------+
# |CODIGO_SINIESTRO|FECHA_SINIESTRO|     HORA_SINIESTRO|CLASE_SINIESTRO|CANTIDAD_DE_FALLECIDOS|CANTIDAD_DE_LESIONADOS|CANTIDAD_DE_VEHICULOS_DANADOS|DEPARTAMENTO|PROVINCIA|            DISTRITO|  ZONA|TIPO_DE_VIA|RED_VIAL| COD_CARRETERA|EXISTE_CICLOVIA|COORDENADAS_LATITUD|COORDENADAS_LONGITUD|CONDICION_CLIMATICA|ZONIFICACION|CARACTERISTICAS_DE_VIA|PERFIL_LONGITUDINAL_VIA|SUPERFICIE_DE_CALZADA|EXISTE_SENAL_VERTICAL|CLASIFICACION_DE_LA_SENAL_VERTICAL_N_1|CLASIFICACION_DE_LA_SENAL_VERTICAL_N_2|EXISTE_SENAL_HORIZONTAL|CAUSA_FACTOR_PRINCIPAL|    CAUSA_ESPECIFICA|
# +----------------+---------------+-------------------+---------------+----------------------+----------------------+-----------------------------+------------+---------+--------------------+------+-----------+--------+--------------+---------------+-------------------+--------------------+-------------------+------------+----------------------+-----------------------+---------------------+---------------------+--------------------------------------+--------------------------------------+-----------------------+----------------------+--------------------+
# |    A-2021-01-23|     01/01/2021|2025-11-17 04:40:00|       DESPISTE|                     1|                     0|                            1|        LIMA|   HUARAL|              HUARAL| RURAL|  CARRETERA| VECINAL|        LM-671|             NO|   -11.482879238488|   -77.2555467597152|          DESPEJADO|       RURAL|           TRAMO RECTO|                 PLANA |               TROCHA|                 null|                                  null|                                  null|                   null|  NO IDENTIFICA LA ...|                null|
# |   A-2021-01-248|     01/01/2021|2025-11-17 05:45:00|       DESPISTE|                     1|                     3|                            0|        LIMA|     LIMA|          PACHACAMAC|URBANA|    AVENIDA|  URBANO|NO CORRESPONDE|             NO|           -12.2294|          -76.859412|          DESPEJADO|  INDUSTRIAL|           TRAMO RECTO|                 PLANA |            ASFALTADA|                 null|                                  null|                                  null|                   null|  IMPRUDENCIA DEL C...|CONDUCIR EN ESTAD...|
# |    A-2021-01-38|     01/01/2021|2025-11-17 06:00:00| ATROPELLO FUGA|                     2|                     0|                         null| LA LIBERTAD|     VIRU|                VIRU|URBANA|  CARRETERA| VECINAL|       LI-1150|             NO|          -8.414865|          -78.754544|          DESPEJADO|   COMERCIAL|           TRAMO RECTO|                 PLANA |            ASFALTADA|                 null|                                  null|                                  null|                   null|  NO IDENTIFICA LA ...|                null|
# |    A-2021-01-39|     01/01/2021|2025-11-17 07:00:00|         CHOQUE|                     1|                     0|                            2| LA LIBERTAD|     VIRU|                VIRU| RURAL|  CARRETERA|NACIONAL|         PE-1N|             NO|          -8.432617|          -78.772242|          DESPEJADO|       RURAL|           TRAMO RECTO|                 PLANA |            ASFALTADA|                 null|                                  null|                                  null|                   null|  IMPRUDENCIA DEL C...|GIRAR IMPRUDENTEM...|
# |   A-2021-01-254|     01/01/2021|2025-11-17 14:00:00|      ATROPELLO|                     1|                     1|                            0|        LIMA|     LIMA|VILLA MARIA DEL T...|URBANA|    AVENIDA|  URBANO|NO CORRESPONDE|             NO|         -12.164406|          -76.953426|          DESPEJADO|  INDUSTRIAL|           TRAMO RECTO|                 PLANA |            ASFALTADA|                 null|                                  null|                                  null|                   null|  IMPRUDENCIA DEL C...|CONDUCIR EN ESTAD...|
# +----------------+---------------+-------------------+---------------+----------------------+----------------------+-----------------------------+------------+---------+--------------------+------+-----------+--------+--------------+---------------+-------------------+--------------------+-------------------+------------+----------------------+-----------------------+---------------------+---------------------+--------------------------------------+--------------------------------------+-----------------------+----------------------+--------------------+
# only showing top 5 rows

# %% [markdown]
# ## ETAPA 2 – TRANSFORMACIÓN EN MODELO ESTRELLA

# %% [markdown]
# ### 1. Iniciar sesión Spark

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder.appName("ETL_SUTRAN").getOrCreate()

# %% [markdown]
# ### 2. Leer y limpiar los CSV desde Cloud Storage

# %% [markdown]
# 2.1 Definir función para limpiar columnas (quita BOM, espacios, etc.)

# %%
from pyspark.sql.functions import col

def limpiar_columnas(df):
    return df.select([col(c).alias(c.strip().replace("ï»¿", "").replace("\ufeff", "")) for c in df.columns])

# %% [markdown]
# 2.2 Leer datasets

# %%
bucket = "sutran-bucket-2025"
path_raw = f"gs://{bucket}/raw/"

# Personas
personas = spark.read.option("header", "true") \
    .option("encoding", "ISO-8859-1") \
    .csv(path_raw + "BBDD_ONSV-PERSONAS_2021-2023.csv")

personas_clean = limpiar_columnas(personas)

# Vehículos
vehiculos = spark.read.option("header", "true") \
    .option("encoding", "ISO-8859-1") \
    .csv(path_raw + "BBDD_ONSV-VEHICULOS_2021-2023.csv")

vehiculos_clean = limpiar_columnas(vehiculos)

# Siniestros
siniestros = spark.read.option("header", "true") \
    .option("encoding", "ISO-8859-1") \
    .csv(path_raw + "BBDD_ONSV-SINIESTROS_2021-2023.csv")

siniestros_clean = limpiar_columnas(siniestros)

# Cast columnas numéricas en siniestros
siniestros_clean = siniestros_clean \
    .withColumn("CANTIDAD_DE_FALLECIDOS", col("CANTIDAD_DE_FALLECIDOS").cast("int")) \
    .withColumn("CANTIDAD_DE_LESIONADOS", col("CANTIDAD_DE_LESIONADOS").cast("int")) \
    .withColumn("CANTIDAD_DE_VEHICULOS_DANADOS", col("CANTIDAD_DE_VEHICULOS_DANADOS").cast("int"))

# %% [markdown]
# ### 3. Crear tablas del modelo estrella

# %% [markdown]
# 3.1 dim_persona

# %%
dim_persona = personas_clean.select(
    "CODIGO_PERSONA",
    "SEXO",
    "EDAD",
    "CLASE_LICENCIA",
    "PAIS_DE_NACIONALIDAD",
    "POSEE_LICENCIA",
    "RESULTADO_DEL_DOSAJE_ETILICO_CUALITATIVO", #Aca se hizo cambio registrar en bitácora
    "SITUACION_DE_PERSONA",
    "GRAVEDAD"
).dropDuplicates(["CODIGO_PERSONA"])

# %% [markdown]
# 3.2 dim_vehiculo

# %%
dim_vehiculo = vehiculos_clean.select(
    "CODIGO_VEHICULO",
    "VEHICULO",
    "MODALIDAD_DE_TRANSPORTE",
    "TIPO_SEGURO",
    "COMPANIA_SEGURO",
    "ESTADO_CITV",
    "ESTADO_SOAT",
    "ESTADO_MODALIDAD",
    "SITUACION_VEHICULO"
).dropDuplicates(["CODIGO_VEHICULO"])

# %% [markdown]
# 3.3 dim_tiempo

# %%
from pyspark.sql.functions import to_date, year, month, dayofmonth

siniestros_clean = siniestros_clean.withColumn("FECHA", to_date("FECHA_SINIESTRO", "yyyy-MM-dd"))

dim_tiempo = siniestros_clean.select("FECHA").distinct() \
    .withColumn("ANO", year("FECHA")) \
    .withColumn("MES", month("FECHA")) \
    .withColumn("DIA", dayofmonth("FECHA")) \
    .withColumn("ID_TIEMPO", col("FECHA").cast("string"))

# %% [markdown]
# 3.4 dim_tipo_via

# %%
from pyspark.sql.functions import monotonically_increasing_id

dim_tipo_via = siniestros_clean.select(
    "TIPO_DE_VIA",
    "PERFIL_LONGITUDINAL_VIA",
    "SUPERFICIE_DE_CALZADA",
    "ZONIFICACION"
).dropDuplicates()

dim_tipo_via = dim_tipo_via.withColumn("ID_TIPO_VIA", monotonically_increasing_id())

# %% [markdown]
# 3.5 f_siniestro (tabla de hechos)

# %%
f_siniestro = siniestros_clean.select(
    "CODIGO_SINIESTRO",
    "FECHA",
    "TIPO_DE_VIA",
    "CAUSA_FACTOR_PRINCIPAL",
    "CLASE_SINIESTRO",
    "COORDENADAS_LATITUD",
    "CANTIDAD_DE_FALLECIDOS",
    "CANTIDAD_DE_LESIONADOS",
    "CANTIDAD_DE_VEHICULOS_DANADOS"
)

# %% [markdown]
# ### 4. Cargar tablas a BigQuery

# %%
# Proyecto y dataset
bq_project = "shaped-icon-478404-p0"
bq_dataset = "bi_sutran"

# %% [markdown]
# 4.1 Subir dim_persona

# %%
dim_persona.write \
    .format("bigquery") \
    .option("table", f"{bq_project}.{bq_dataset}.dim_persona") \
    .option("temporaryGcsBucket", "sutran-bucket-2025") \
    .mode("overwrite") \
    .save()

# %% [markdown]
# 4.2 Lo mismo para las demás dimensiones

# %%
dim_vehiculo.write.format("bigquery").option("table", f"{bq_project}.{bq_dataset}.dim_vehiculo").option("temporaryGcsBucket", "sutran-bucket-2025").mode("overwrite").save()

dim_tiempo.write.format("bigquery").option("table", f"{bq_project}.{bq_dataset}.dim_tiempo").option("temporaryGcsBucket", "sutran-bucket-2025").mode("overwrite").save()

dim_tipo_via.write.format("bigquery").option("table", f"{bq_project}.{bq_dataset}.dim_tipo_via").option("temporaryGcsBucket", "sutran-bucket-2025").mode("overwrite").save()

f_siniestro.write.format("bigquery").option("table", f"{bq_project}.{bq_dataset}.f_siniestro").option("temporaryGcsBucket", "sutran-bucket-2025").mode("overwrite").save()
