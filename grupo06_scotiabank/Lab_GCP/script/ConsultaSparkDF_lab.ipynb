# %%
ruta_hdfs = "/labGCP/flights.csv"

flightsDF = spark.read\
            .option("header", "true")\
            .option("inferSchema", "true")\
            .csv(ruta_hdfs)

# %%
flightsDF.show(5)

# %%
flightsDF.printSchema()
