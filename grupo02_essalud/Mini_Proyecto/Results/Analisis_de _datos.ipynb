# %% [markdown]
# # 📊 Análisis Exploratorio de Datos (EDA) — Dataset de Netflix
# ## 1. Introducción
#
# El presente análisis se realizó sobre el dataset **“Netflix Movies and TV Shows”**, obtenido desde Kaggle.
# Este conjunto de datos contiene información sobre títulos disponibles en la plataforma de Netflix, incluyendo tipo, país, año de lanzamiento, duración, clasificación, y géneros.
#
# El propósito del análisis es **entender la composición del catálogo**, identificar patrones temporales y de contenido, y preparar los datos para futuros análisis más avanzados (recomendaciones, segmentaciones o dashboards).
#
# ---
#
# ## 2. Descripción general del dataset
#
# | Atributo | Descripción |
# |-----------|-------------|
# | **show_id** | Identificador único del título |
# | **type** | Tipo de contenido: “Movie” o “TV Show” |
# | **title** | Nombre de la producción |
# | **director** | Director principal |
# | **cast** | Reparto principal |
# | **country** | País de origen |
# | **date_added** | Fecha en que fue añadido a Netflix |
# | **release_year** | Año de lanzamiento |
# | **rating** | Clasificación por edad (TV-MA, PG, etc.) |
# | **duration** | Duración en minutos o número de temporadas |
# | **listed_in** | Categorías o géneros asociados |
# | **description** | Breve sinopsis del título |
#
# ---
#
# ## 3. Calidad de los datos
#
# Se identificaron valores nulos principalmente en las columnas **director (29.91%)**, **country (9.44%)** y **cast (9.37%)**, los cuales fueron tratados durante la limpieza de datos.
#
# ```python
# missing = df.isna().sum().sort_values(ascending=False)
# (missing / len(df) * 100).round(2)
# ```
#
# ## 4. Distribución general del contenido
#
# ### 📺 Cantidad por tipo (Movies vs TV Shows)
#
# El análisis inicial de la variable **`type`** revela que el catálogo de Netflix está compuesto por dos tipos principales de contenido: **películas (Movies)** y **series de televisión (TV Shows)**.
# La proporción observada es aproximadamente **69% películas** y **31% series**, lo que demuestra una clara predominancia del formato cinematográfico dentro de la plataforma.
#
# Esta diferencia no solo responde a la estrategia inicial de Netflix, que comenzó como un servicio de distribución de películas por streaming, sino también a la naturaleza de la producción audiovisual: las películas suelen requerir menor inversión continua y pueden adquirirse a través de licencias preexistentes, mientras que las series implican producción por temporadas, contratos prolongados y seguimiento narrativo.
#
# ![Cantidad por tipo](Raw_Cantidad_Tipo.png)
#
# **Interpretación ampliada:**
#
# - 📈 **Predominio del formato cinematográfico:**
#   Netflix ha mantenido una fuerte inclinación hacia las películas, principalmente por la facilidad de adquisición de derechos y su atractivo inmediato para nuevos suscriptores.
#   Esto explica que más de dos tercios del catálogo total correspondan a películas.
#
# - 🎬 **Estrategia de diversificación:**
#   A partir de 2015, con el éxito de producciones originales como *House of Cards* o *Stranger Things*, la empresa comenzó a invertir fuertemente en series.
#   Aunque el número total de películas aún supera al de series, la tendencia muestra un crecimiento sostenido del formato episódico.
#
# - 🌍 **Distribución geográfica del contenido:**
#   La mayor presencia de películas también refleja la inclusión de producciones internacionales, muchas de ellas provenientes de Estados Unidos, India y Reino Unido, países con una industria cinematográfica sólida y acuerdos de distribución con Netflix.
#
# - 👥 **Preferencias del usuario:**
#   El formato de película permite un consumo más rápido y autoconclusivo, lo que se adapta mejor a los hábitos de visualización de usuarios que buscan contenido de corta duración o con historias cerradas.
#   En cambio, las series fomentan la retención a largo plazo y el engagement, un aspecto que Netflix ha comenzado a potenciar en los últimos años.
#
# En conjunto, esta distribución refleja tanto **la herencia del modelo inicial de Netflix** (centrado en películas licenciadas), como **su evolución hacia un equilibrio más variado**, impulsado por la producción de contenido original y la diversificación internacional.
#
# ## 5. Años de lanzamiento
#
# ### 📆 Distribución temporal de los títulos
#
# El análisis de la variable **`release_year`** permite identificar las tendencias de producción y adquisición de contenido dentro del catálogo de Netflix a lo largo del tiempo.
# Los datos muestran una **mayor concentración de títulos entre los años 2010 y 2021**, con un crecimiento sostenido desde inicios del siglo XXI y un **pico notable entre 2018 y 2020**.
#
# ![Distribución de años](Raw_Distribucion_Años_Lanzamiento.png)
#
# **Observaciones clave:**
#
# - 🔹 Antes del año 2000, el número de títulos disponibles es reducido, concentrándose en producciones clásicas o licenciadas.
# - 🔹 A partir del año 2000, se observa un **incremento progresivo**, lo que refleja la expansión de los derechos de distribución digital y la consolidación de Netflix como plataforma de streaming.
# - 🔹 Entre **2015 y 2020**, el crecimiento se vuelve exponencial, alcanzando su punto más alto en 2019.
# - 🔹 A partir de 2020, se nota una ligera reducción, posiblemente relacionada con el impacto de la pandemia en la producción audiovisual global.
#
# ### 🧠 Interpretación detallada
#
# El aumento en el número de títulos lanzados a partir de 2010 coincide con la **estrategia de expansión internacional** de Netflix y su transición de distribuidor a **productor de contenido original**.
# Con el lanzamiento de *Netflix Originals* en 2013 y la introducción de producciones locales en diferentes países, la compañía amplió su catálogo de manera acelerada.
#
# Este crecimiento refleja varios factores clave:
#
# - **📈 Expansión global:**
#   Netflix pasó de operar en unos pocos países a estar disponible en más de 190, lo que impulsó la adquisición de licencias regionales y contenido adaptado a diferentes mercados.
#
# - **🎬 Producción original:**
#   A partir de 2015, la empresa invirtió fuertemente en la creación de contenido propio, reduciendo su dependencia de estudios externos.
#   Ejemplos emblemáticos incluyen *Narcos* (2015), *The Crown* (2016), y *Stranger Things* (2016).
#
# - **🧩 Cambios en el consumo de medios:**
#   La era digital impulsó el consumo bajo demanda, haciendo que Netflix apostara por un modelo de estrenos constantes para mantener la atención de los usuarios.
#
# - **🦠 Efecto pandemia (2020–2021):**
#   El descenso leve tras 2020 podría deberse a la paralización de producciones por las restricciones sanitarias, aunque la demanda de streaming aumentó.
#
# En resumen, la evolución temporal del catálogo evidencia una **fase de consolidación y expansión acelerada**, impulsada por la producción original y la adaptación al mercado global.
# Netflix ha pasado de ser un repositorio de contenido externo a un **ecosistema propio de distribución y creación audiovisual**, reflejado claramente en el aumento de títulos durante la última década.
#
# ## 6. Análisis de duración (películas)
#
# ### 🎬 Distribución de la duración
#
# El análisis de la variable **`duration`**, transformada en minutos mediante la función `parse_duration`, permite estudiar la extensión promedio de las películas disponibles en Netflix.
# Los resultados muestran que la mayoría de producciones se concentran en un rango entre **80 y 120 minutos**, con una ligera cúspide en torno a los **90 minutos**, lo que coincide con la duración típica del cine comercial contemporáneo.
#
# ![Duración](Raw_Duracion_peliculas.png)
#
# **Observaciones clave:**
#
# - 🔹 La mayoría de las películas siguen una duración estándar de **1 hora y 30 minutos** aproximadamente.
# - 🔹 Existen algunos valores atípicos con duraciones muy altas (más de 180 minutos) que corresponden a producciones especiales o documentales extensos.
# - 🔹 También se identifican valores nulos o registros con **duración igual a 0**, asociados a errores de registro o títulos clasificados erróneamente como “Movies” pero que en realidad son series o cortometrajes.
#
# ### 🧠 Interpretación detallada
#
# La duración de las películas disponibles en Netflix refleja una **adaptación estratégica al formato de streaming**, que prioriza la accesibilidad y el ritmo de consumo del usuario.
# Al mantener la duración dentro del rango tradicional del cine, la plataforma garantiza una experiencia compatible con los hábitos de visualización doméstica.
#
# **Factores explicativos:**
#
# - **📺 Consumo en streaming:**
#   El público actual tiende a preferir contenidos de menor duración que puedan verse en una sola sesión. Por ello, Netflix equilibra su catálogo entre películas “ligeras” y producciones de larga duración.
#
# - **🎞️ Estandarización cinematográfica:**
#   El rango de 80–120 minutos coincide con la estructura narrativa de tres actos, ampliamente usada en la industria del cine.
#   Esto facilita la distribución y mantiene la familiaridad del espectador.
#
# - **🌍 Diversidad de origen:**
#   Las duraciones varían según el país:
#   - En Estados Unidos y Reino Unido predominan películas de 90–110 minutos.
#   - En India o países asiáticos, algunas producciones pueden superar las 150 minutos debido a diferencias culturales y de estilo narrativo.
#
# - **⚙️ Oportunidades de mejora:**
#   Los registros con duración anómala o nula deben ser revisados o corregidos, ya que pueden afectar análisis estadísticos o modelos predictivos posteriores.
#
# Netflix mantiene una **consistencia en la duración promedio de sus películas**, siguiendo los estándares internacionales del cine comercial, pero también adaptándose a las nuevas formas de consumo digital.
# Esta estabilidad indica un equilibrio entre la tradición cinematográfica y la optimización del contenido para plataformas en línea.
#
# ## 7. Correlación entre variables numéricas
#
# ### 📈 Análisis de correlaciones
#
# Para identificar posibles relaciones entre las variables numéricas del dataset, se seleccionaron los campos cuantitativos y se calculó la matriz de correlación.
# En este caso, las variables analizadas fueron principalmente **`release_year`** (año de lanzamiento) y **`duration_minutes`** (duración convertida a minutos).
#
# ![Correlación](Raw_Relacion_Año_Duracion.png)
#
# **Resultados principales:**
#
# - 🔹 Se observó una **correlación negativa débil** entre `release_year` y `duration_minutes`, con un coeficiente de aproximadamente **–0.25**.
# - 🔹 Esto significa que, en promedio, las **películas más recientes tienden a tener una menor duración** que las producidas en años anteriores.
# - 🔹 No se identificaron correlaciones significativas entre otras variables numéricas, lo que indica que la duración y el año son las dimensiones cuantitativas más relevantes para este tipo de análisis.
#
# ---
#
# ### 🧠 Interpretación detallada
#
# La correlación negativa sugiere una **tendencia progresiva hacia la reducción en la duración de las películas** conforme se acercan a los años más recientes.
# Este patrón, aunque leve, refleja **cambios estructurales en la industria del entretenimiento y en el comportamiento del consumidor moderno**.
#
# **Posibles causas del fenómeno:**
#
# - **📱 Nuevos hábitos de consumo digital:**
#   Los usuarios de plataformas de streaming tienden a consumir contenido de manera fragmentada o en intervalos cortos, lo que incentiva la creación de películas más dinámicas y concisas.
#
# - **🎬 Enfoque en ritmo narrativo:**
#   Las producciones actuales buscan captar la atención del espectador desde los primeros minutos.
#   Se priorizan guiones más ágiles, ediciones rápidas y tiempos narrativos reducidos para mantener el interés.
#
# - **🌐 Competencia entre plataformas:**
#   El auge de múltiples servicios de streaming (Amazon Prime, Disney+, HBO Max, etc.) ha impulsado la diversificación de formatos y duraciones, incluyendo películas intermedias (60–80 min) o antologías.
#
# - **🎥 Producción orientada a lo digital:**
#   La reducción en duración también puede atribuirse al menor costo de producción y a la mayor flexibilidad en la publicación de contenido exclusivo para plataformas digitales, que no dependen de los horarios de cine tradicionales.
#
# ---
#
# Aunque la relación entre año y duración no es muy fuerte, el análisis evidencia una **evolución en la estructura del contenido cinematográfico moderno**.
# Netflix y otras plataformas tienden a ofrecer **películas más cortas, ágiles y accesibles**, adaptadas a la era del consumo inmediato y al público digital.
#
# Este cambio refleja no solo una tendencia técnica, sino también **una transformación cultural en la forma en que las audiencias perciben y disfrutan el contenido audiovisual**.
#
# ## 8. Géneros más frecuentes
#
# ### 🎭 Análisis
#
# ![Géneros más frecuentes](Generos_mas_frecuentes_en_Netflix.png)
#
# El análisis de la variable **`listed_in`**, que contiene los géneros asociados a cada título, permite comprender la composición temática del catálogo de Netflix.
# Dado que muchos títulos incluyen múltiples géneros, se realizó una separación de los valores por comas para obtener una visión más precisa.
# Los resultados indican que los géneros más comunes son **International Movies**, **Dramas** y **Comedies**, seguidos de **International TV Shows** y **Documentaries**.
#
# **Interpretación ampliada:**
#
# - 🎬 **Diversidad de géneros y culturas:**
#   La categoría “International Movies” encabeza el ranking, reflejando el carácter global de Netflix y su estrategia de internacionalización.
#   Esta tendencia evidencia una fuerte apuesta por producciones de diferentes países, idiomas y estilos narrativos.
#
# - 🎭 **Predominio de dramas y comedias:**
#   Ambos géneros se encuentran en casi todos los mercados y son los más efectivos para atraer públicos amplios.
#   Netflix equilibra entre el entretenimiento ligero (comedias) y los relatos profundos o emocionales (dramas).
#
# - 📺 **Crecimiento de documentales y series internacionales:**
#   El auge de los documentales demuestra el interés por contenido educativo, social o biográfico.
#   A su vez, los “International TV Shows” destacan la expansión de la plataforma hacia producciones regionales, especialmente en Asia y Latinoamérica.
#
# **Conclusión:**
# El catálogo de Netflix presenta una clara **diversidad temática y cultural**, dominada por dramas, comedias y películas internacionales, lo que refuerza su enfoque global y su estrategia de satisfacer audiencias con gustos variados.
# ---
#
#
# ##  9 Países con mayor número de títulos
#
# ### Análisis
#
# ![Países con más títulos](Paises_con_mas_titulos.png)
#
# El análisis de la variable **`country`** permite identificar las regiones con mayor presencia dentro del catálogo.
# Después de separar los países por comas y agrupar los valores, se observó que **Estados Unidos**, **India** y **Reino Unido** son los principales productores de contenido disponible en la plataforma, seguidos por **Canadá**, **Francia**, **Japón** y **España**.
#
# **Interpretación ampliada:**
#
# - 🇺🇸 **Estados Unidos** domina claramente el catálogo, lo cual refleja la herencia del cine de Hollywood y su rol histórico como principal exportador de contenido audiovisual.
#   Netflix ha adquirido licencias de múltiples estudios estadounidenses, fortaleciendo su base de películas comerciales y series reconocidas.
#
# - 🇮🇳 **India** ocupa el segundo lugar, impulsada por la popularidad del cine de Bollywood y la producción creciente de contenido original para el mercado asiático.
#   Este crecimiento responde a la alta demanda local y al interés internacional por producciones de esa región.
#
# - 🇬🇧 **Reino Unido** y 🇨🇦 **Canadá** aportan una cantidad significativa de títulos, en su mayoría dramas, comedias y documentales.
#   Estas naciones son aliados estratégicos para coproducciones y contenido de exportación.
#
# - 🌐 **Otros países** como Francia, Japón, Corea del Sur y España, han incrementado su presencia gracias a títulos exitosos (*Lupin*, *Alice in Borderland*, *La Casa de Papel*), que reflejan la **globalización de la narrativa audiovisual**.
#
# **Conclusión:**
# Netflix combina una fuerte base de contenido estadounidense con una **diversificación internacional** creciente, lo que le permite competir en mercados globales y fortalecer su identidad multicultural.
# ---
#
# ## 10 Clasificaciones por edad (Rating)
#
# ### Análisis
#
# ![Clasificación por edad](Clasificaciones_por_edad.png)
#
# El análisis de la variable **`rating`** muestra cómo se distribuyen los títulos según su clasificación por edad.
# Los resultados más frecuentes corresponden a **TV-MA (solo adultos)**, **TV-14 (mayores de 14 años)** y **TV-PG (supervisión parental sugerida)**.
#
# **Interpretación ampliada:**
#
# - 📈 **Predominio de contenido para adultos y adolescentes:**
#   La mayoría de los títulos están clasificados como **TV-MA**, seguidos de **TV-14**, lo que indica que Netflix prioriza contenido orientado a audiencias maduras.
#   Esto incluye dramas, thrillers, documentales y comedias con temáticas más complejas.
#
# - 👨‍👩‍👧 **Presencia limitada de contenido infantil:**
#   Las clasificaciones **TV-Y**, **TV-G** y **PG** representan un porcentaje menor.
#   Si bien existen producciones familiares y animadas, estas no constituyen el foco principal del catálogo, que busca captar al público joven-adulto, el más activo en plataformas digitales.
#
# - 🧭 **Estrategia de segmentación:**
#   La distribución de ratings refleja una estrategia de segmentación que equilibra el entretenimiento masivo con contenido selectivo y diferenciado.
#   Netflix mantiene su identidad de plataforma libre de restricciones tradicionales, lo que le permite abordar temáticas más diversas y realistas.
#
# ## 🧩 Conclusión General
#
# El análisis exploratorio del catálogo de **Netflix** revela una plataforma que ha evolucionado significativamente desde sus inicios como distribuidor de películas hacia un **ecosistema global de producción y distribución audiovisual**.
# Los resultados evidencian una **predominancia de películas (≈69%)** sobre series, reflejo de su modelo original de negocio, aunque con una tendencia clara hacia la diversificación y el crecimiento del formato episódico en los últimos años.
#
# En términos **temporales**, se observa un aumento sostenido en la cantidad de títulos entre **2010 y 2020**, impulsado por la expansión internacional de la empresa, la producción de contenido original (*Netflix Originals*) y la consolidación del consumo bajo demanda.
# Este crecimiento marca el paso de Netflix de ser un repositorio de licencias externas a un **productor global de contenido propio**, con presencia en más de 190 países.
#
# El análisis de **duración** muestra que la mayoría de películas mantienen una longitud estándar entre **80 y 120 minutos**, lo que responde tanto a los cánones narrativos del cine tradicional como a los nuevos hábitos de consumo digital que priorizan experiencias breves, dinámicas y autoconclusivas.
# La **correlación negativa** entre año de lanzamiento y duración sugiere una adaptación progresiva del contenido a la atención limitada del público contemporáneo.
#
# En cuanto a **géneros**, el catálogo destaca por su **diversidad cultural y temática**, dominada por *International Movies*, *Dramas* y *Comedies*.
# Esto refleja una estrategia de internacionalización y localización simultánea, donde la empresa busca conectar con diferentes mercados sin perder su identidad global.
# A nivel **geográfico**, países como **Estados Unidos, India y Reino Unido** lideran la producción disponible, consolidando alianzas estratégicas y fortaleciendo la oferta internacional.
#
# Finalmente, la distribución de **clasificaciones por edad (ratings)** evidencia un enfoque hacia **audiencias jóvenes y adultas**, con predominio de contenido **TV-MA** y **TV-14**, reafirmando la orientación de Netflix hacia una oferta más madura, diversa y libre de censura tradicional.
#
# En conjunto, el análisis muestra que Netflix ha logrado **equilibrar cantidad, variedad y enfoque estratégico**, construyendo un catálogo que combina la herencia del cine tradicional con las demandas del consumo digital moderno.
# Su evolución refleja no solo una transformación empresarial, sino también un **cambio cultural global en la forma de crear, distribuir y consumir entretenimiento audiovisual**.
