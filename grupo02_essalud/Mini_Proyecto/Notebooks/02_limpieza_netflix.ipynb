# %% [markdown]
# # Limpieza de datos

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("/Mini_Proyecto/Data/Raw/netflix_titles.csv")

# Contar valores faltantes (NaN)
missing_count = df.isna().sum().sort_values(ascending=False)
missing_percent = (missing_count / len(df) * 100).round(2)

# Mostrar resumen ordenado
missing_df = pd.DataFrame(
    {"missing_count": missing_count, "missing_percent": missing_percent}
)
missing_df
# Out:
#               missing_count  missing_percent
# director               1883            34.88
# country                 663            12.28
# cast                    495             9.17
# title                     1             0.02
# rating                    1             0.02
# duration                  1             0.02
# date_added                1             0.02
# release_year              1             0.02
# listed_in                 1             0.02
# description               1             0.02
# show_id                   0             0.00
# type                      0             0.00

# %% [markdown]
# Borrando filas vacías en campos específicos

# %%
cols_importantes = ["type", "country", "release_year"]
df_clean = df.dropna(subset=cols_importantes).reset_index(drop=True)
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4735 entries, 0 to 4734
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       4735 non-null   object
#  1   type          4735 non-null   object
#  2   title         4735 non-null   object
#  3   director      3161 non-null   object
#  4   cast          4360 non-null   object
#  5   country       4735 non-null   object
#  6   date_added    4735 non-null   object
#  7   release_year  4735 non-null   float64
#  8   rating        4735 non-null   object
#  9   duration      4735 non-null   object
#  10  listed_in     4735 non-null   object
#  11  description   4735 non-null   object
# dtypes: float64(1), object(11)
# memory usage: 444.0+ KB

# %%
df_clean.to_csv("/Mini_Proyecto/Data/Processed/netflix_clean.csv", index=False)
print("✅ Dataset limpio guardado en data/processed/netflix_clean.csv")
# Out:
# ✅ Dataset limpio guardado en data/processed/netflix_clean.csv
